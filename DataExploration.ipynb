# %%
import pandas as pd

df = pd.read_csv('./dftRoadCasualtyStatisticsAccident19792021.csv')
# Out:
# C:\Users\fiona.havelock\AppData\Local\Temp\ipykernel_10412\344972350.py:3: DtypeWarning: Columns (0,2,15,16,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('C:\\Users\\fiona.havelock\\Documents\\FinalProject\\dftRoadCasualtyStatisticsAccident19792021.csv')

# %%
df.head()
# Out:
#   accident_index  accident_year accident_reference  location_easting_osgr  \
# 0  197901A11AD14           1979          01A11AD14                    NaN
# 1  197901A1BAW34           1979          01A1BAW34               198460.0
# 2  197901A1BFD77           1979          01A1BFD77               406380.0
# 3  197901A1BGC20           1979          01A1BGC20               281680.0
# 4  197901A1BGF95           1979          01A1BGF95               153960.0
#
#    location_northing_osgr  longitude  latitude  police_force  \
# 0                     NaN        NaN       NaN             1
# 1                894000.0        NaN       NaN             1
# 2                307000.0        NaN       NaN             1
# 3                440000.0        NaN       NaN             1
# 4                795000.0        NaN       NaN             1
#
#    accident_severity  number_of_vehicles  ...  \
# 0                  3                   2  ...
# 1                  3                   1  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8703911 entries, 0 to 8703910
# Data columns (total 36 columns):
#  #   Column                                       Dtype
# ---  ------                                       -----
#  0   accident_index                               object
#  1   accident_year                                int64
#  2   accident_reference                           object
#  3   location_easting_osgr                        float64
#  4   location_northing_osgr                       float64
#  5   longitude                                    float64
#  6   latitude                                     float64
#  7   police_force                                 int64
#  8   accident_severity                            int64
#  9   number_of_vehicles                           int64
#  10  number_of_casualties                         int64
#  11  date                                         object
#  12  day_of_week                                  int64
# ...

# %%
import seaborn as sns

# %%
# missing data analysis
#variable analysis
sns.heatmap(df.isna().transpose(),
            cmap="YlGnBu",
            cbar_kws={'label': 'Missing Data'})
# Out:
# <AxesSubplot: >

# %%
percent_missing = df.isnull().sum() * 100 / len(df)
missing_value_df = pd.DataFrame({'column_name': df.columns,
                                 'percent_missing': percent_missing})

# %%
missing_value_df.head()
# Out:
#                                    column_name  percent_missing
# accident_index                  accident_index          0.00000
# accident_year                    accident_year          0.00000
# accident_reference          accident_reference          0.00000
# location_easting_osgr    location_easting_osgr          0.13371
# location_northing_osgr  location_northing_osgr          0.13371

# %%
sns.barplot(data=missing_value_df, y="column_name", x="percent_missing",)
# Out:
# <AxesSubplot: xlabel='percent_missing', ylabel='column_name'>

# %%
# Count total NaN at each column in a DataFrame
print(" \nCount total NaN at each column in a DataFrame : \n\n",
      df.isnull().sum())
# Out:
#
# Count total NaN at each column in a DataFrame :
#
#  accident_index                                       0
# accident_year                                        0
# accident_reference                                   0
# location_easting_osgr                            11638
# location_northing_osgr                           11638
# longitude                                      4887419
# latitude                                       4887419
# police_force                                         0
# accident_severity                                    0
# number_of_vehicles                                   0
# number_of_casualties                                 0
# date                                                 8
# day_of_week                                          0
# time                                                 8
# local_authority_district                             0
# local_authority_ons_district                         0
# ...

# %%
train = df.sample(frac=0.05,random_state=0)

# %%
train.head()
# Out:
#         accident_index  accident_year accident_reference  \
# 6697117  2007230791391           2007          230791391
# 2660964  19894200H1069           1989          4200H1069
# 7447434  201201RG40048           2012          01RG40048
# 6683595  200720F091701           2007          20F091701
# 3541661  199306X009893           1993          06X009893
#
#          location_easting_osgr  location_northing_osgr  longitude   latitude  \
# 6697117               414050.0                256110.0  -1.795841  52.203006
# 2660964               585000.0                187600.0        NaN        NaN
# 7447434               540080.0                176880.0   0.015570  51.473493
# 6683595               406660.0                287340.0  -1.903367  52.483912
# 3541661               377200.0                403100.0        NaN        NaN
#
#          police_force  accident_severity  number_of_vehicles  ...  \
# 6697117            23                  3                   3  ...
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 435196 entries, 6697117 to 6879640
# Data columns (total 36 columns):
#  #   Column                                       Non-Null Count   Dtype
# ---  ------                                       --------------   -----
#  0   accident_index                               435196 non-null  object
#  1   accident_year                                435196 non-null  int64
#  2   accident_reference                           435196 non-null  object
#  3   location_easting_osgr                        434624 non-null  float64
#  4   location_northing_osgr                       434624 non-null  float64
#  5   longitude                                    191475 non-null  float64
#  6   latitude                                     191475 non-null  float64
#  7   police_force                                 435196 non-null  int64
#  8   accident_severity                            435196 non-null  int64
# ...

# %%
print(train.corr())
# Out:
# C:\Users\fiona.havelock\AppData\Local\Temp\ipykernel_10412\2017316234.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(train.corr())
#                                              accident_year  \
# accident_year                                     1.000000
# location_easting_osgr                             0.105452
# location_northing_osgr                           -0.043558
# longitude                                         0.053027
# latitude                                         -0.042381
# police_force                                     -0.005862
# accident_severity                                 0.093498
# number_of_vehicles                                0.072749
# number_of_casualties                              0.016292
# day_of_week                                      -0.013440
# ...

# %%
dataplot = sns.heatmap(train.corr(), cmap="YlGnBu", annot=False)
# Out:
# C:\Users\fiona.havelock\AppData\Local\Temp\ipykernel_10412\3209165309.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataplot = sns.heatmap(train.corr(), cmap="YlGnBu", annot=False)

# %%
sns.pairplot(train[['weather_conditions', 'junction_control', 'day_of_week', 'accident_severity' ]])

# %%
sns.barplot(data=train, x="day_of_week", y="accident_severity")
# Out:
# <AxesSubplot: xlabel='day_of_week', ylabel='accident_severity'>

# %%
from sklearn.model_selection import train_test_split

train = train_test_split(df, test_size=0.1, random_state=0)
